# %% [markdown]
# ## 2.6 Q学習で迷路を攻略

# %%
# 宣告使用的套件
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 迷宮的初始狀態

# 宣告圖的大小與圖的變數名稱
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 繪製紅色牆壁
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)

# 繪製代表狀態的文字S0～S8
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 設定繪圖範圍與塗銷刻度
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom='off', top='off',
                labelbottom='off', right='off', left='off', labelleft='off')

# 於目前位置S0繪製綠色圓形
line, = ax.plot([0.5], [2.5], marker="o", color='g', markersize=60)
# Out:
# C:\Users\baris\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
# 設定一開始採用何種策略的參數theta_0

# 列為狀態0～7、欄移動方向的↑、→、↓、←
theta_0 = np.array([[np.nan, 1, 1, np.nan],  # s0
                    [np.nan, 1, np.nan, 1],  # s1
                    [np.nan, np.nan, 1, 1],  # s2
                    [1, 1, 1, np.nan],  # s3
                    [np.nan, np.nan, 1, 1],  # s4
                    [1, np.nan, np.nan, np.nan],  # s5
                    [1, np.nan, np.nan, np.nan],  # s6
                    [1, 1, np.nan, np.nan],  # s7、※s8是終點，所以不需採用任何策略
                    ])

# %%
# 自訂策略的參數theta轉換成行動策略pi的函數


def simple_convert_into_pi_from_theta(theta):
    '''單純地計算比例'''

    [m, n] = theta.shape  # 取得theta的矩陣大小
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :])  # 計算比例

    pi = np.nan_to_num(pi)  # 將nan轉換成0

    return pi

# 求得隨機採取行動的策略pi_0
pi_0 = simple_convert_into_pi_from_theta(theta_0)

# %%
# 設定初始的動作價值函數Q

[a, b] = theta_0.shape  # 將列與欄的數字分別存入a與b
Q = np.random.rand(a, b) * theta_0 * 0.1
# * theta0可乘上每個元素，在Q為朝向牆壁的值，將該值設定為nan

# %%
# 建置ε-greedy法


def get_action(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]

    # 決定動作
    if np.random.rand() < epsilon:
        # 根據ε的機率隨機移動
        next_direction = np.random.choice(direction, p=pi_0[s, :])
    else:
        # 採用Q為最大值的動作
        next_direction = direction[np.nanargmax(Q[s, :])]

    # 將動作存入index
    if next_direction == "up":
        action = 0
    elif next_direction == "right":
        action = 1
    elif next_direction == "down":
        action = 2
    elif next_direction == "left":
        action = 3

    return action


def get_s_next(s, a, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
    next_direction = direction[a]  # 動作a的方向

    # 根據動作決定下一個狀態
    if next_direction == "up":
        s_next = s - 3  # 向上移動時，狀態的數字減3
    elif next_direction == "right":
        s_next = s + 1  # 向右移動時，狀態的數字加1
    elif next_direction == "down":
        s_next = s + 3  # 向下移動時，狀態的數字加3
    elif next_direction == "left":
        s_next = s - 1  # 向左移動時，狀態的數字減1

    return s_next

# %%
# 以Q學習更新動作價值函數Q的部分


def Q_learning(s, a, r, s_next, Q, eta, gamma):

    if s_next == 8:  # 抵達終點的情況
        Q[s, a] = Q[s, a] + eta * (r - Q[s, a])

    else:
        Q[s, a] = Q[s, a] + eta * (r + gamma * np.nanmax(Q[s_next,: ]) - Q[s, a])

    return Q

# %%
# 定義以Q學習走出迷宮的函數，輸出狀態、動作的履歷與更新之後的Q


def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi):
    s = 0  # 起點
    a = a_next = get_action(s, Q, epsilon, pi)  # 初始的行動
    s_a_history = [[0, np.nan]]  # 記錄代理器移動軌跡的list

    while (1):  # 在抵達終點之前不斷執行的迴圈
        a = a_next  # 更新動作

        s_a_history[-1][1] = a
        # 將動作代入目前的狀態（由於是最後一個動作，所以index=-1）

        s_next = get_s_next(s, a, Q, epsilon, pi)
        # 儲存下一個狀態

        s_a_history.append([s_next, np.nan])
        # 代入下一個狀態。由於還不知道會是什麼動作，所以先設定為nan

        # 給予報酬，計算下一個動作
        if s_next == 8:
            r = 1  # 若已抵達終點就給予報酬
            a_next = np.nan
        else:
            r = 0
            a_next = get_action(s_next, Q, epsilon, pi)
            # 計算下一個動作a_next

        # 更新價值函數
        Q = Q_learning(s, a, r, s_next, Q, eta, gamma)

        # 結束條件
        if s_next == 8:  # 若已抵達終點，就結束程式
            break
        else:
            s = s_next

    return [s_a_history, Q]

# %%
# 以Q學習走出迷宮

eta = 0.1  # 學習率
gamma = 0.9  # 時間折扣率
epsilon = 0.5  # ε-greedy法的初始值
v = np.nanmax(Q, axis=1)  # 計算價值在每個狀態之下的最大值
is_continue = True
episode = 1

V = []  # 儲存每回合的狀態價值
V.append(np.nanmax(Q, axis=1))  # 計算動作價值在每個狀態下的最大值

while is_continue:  # 不斷執行，直到is_continue等於False為止
    print("回合:" + str(episode))

    # 遞減ε-greedy的值
    epsilon = epsilon / 2

    # 以Q學習走出迷宮，得出移動軌跡與更新之後的Q
    [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0)

    # 狀態價值的變化
    new_v = np.nanmax(Q, axis=1)  # 計算動作價值在每個狀態下的最大值
    print(np.sum(np.abs(new_v - v)))  # 輸出狀態價值的變化
    v = new_v
    V.append(v)  # 追加在這個回合結束時的狀態價值函數

    print("走出迷宮的總步數為" + str(len(s_a_history) - 1) + "步")

    # 重覆執行100回合
    episode = episode + 1
    if episode > 100:
        break
# Out:
# 回合:1
# 0.0005604551303218797
# 走出迷宮的總步數為4步
# 回合:2
# 0.0005181565920461262
# 走出迷宮的總步數為4步
# 回合:3
# 0.00047893847513202914
# 走出迷宮的總步數為4步
# 回合:4
# 0.0004425870008304411
# 走出迷宮的總步數為4步
# 回合:5
# 0.00040890222525058473
# 走出迷宮的總步數為4步
# 回合:6
# 0.00037769724030922713
# 走出迷宮的總步數為4步
# 回合:7
# 0.0003487974112829084
# 走出迷宮的總步數為4步
# 回合:8
# 0.00032203965030142
# 走出迷宮的總步數為4步
# 回合:9
# 0.00029727172500548793
# 走出迷宮的總步數為4步
# 回合:10
# 0.0002743516014883651
# 走出迷宮的總步數為4步
# 回合:11
# 0.00025314682056765125
# 走出迷宮的總步數為4步
# 回合:12
# 0.00023353390636382532
# 走出迷宮的總步數為4步
# 回合:13
# 0.000215397806114348
# 走出迷宮的總步數為4步
# 回合:14
# 0.00019863136012288063
# 走出迷宮的總步數為4步
# 回合:15
# 0.00018313480070875077
# 走出迷宮的總步數為4步
# 回合:16
# 0.00016881527901813076
# 走出迷宮的總步數為4步
# 回合:17
# 0.00015558641854818145
# 走出迷宮的總步數為4步
# 回合:18
# 0.00014336789423463614
# 走出迷宮的總步數為4步
# 回合:19
# 0.00013208503597283983
# 走出迷宮的總步數為4步
# 回合:20
# 0.0001216684554448122
# 走出迷宮的總步數為4步
# 回合:21
# 0.00011205369515132624
# 走出迷宮的總步數為4步
# 回合:22
# 0.00010318089857330737
# 走出迷宮的總步數為4步
# 回合:23
# 9.499450040306723e-05
# 走出迷宮的總步數為4步
# 回合:24
# 8.744293582896301e-05
# 走出迷宮的總步數為4步
# 回合:25
# 8.047836787650198e-05
# 走出迷宮的總步數為4步
# 回合:26
# 7.405643184765776e-05
# 走出迷宮的總步數為4步
# 回合:27
# 6.813599593502584e-05
# 走出迷宮的總步數為4步
# 回合:28
# 6.26789371164227e-05
# 走出迷宮的總步數為4步
# 回合:29
# 5.7649931479386574e-05
# 走出迷宮的總步數為4步
# 回合:30
# 5.3016258151128426e-05
# 走出迷宮的總步數為4步
# 回合:31
# 4.8747616052779996e-05
# 走出迷宮的總步數為4步
# 回合:32
# 4.4815952727095265e-05
# 走出迷宮的總步數為4步
# 回合:33
# 4.1195304526175924e-05
# 走出迷宮的總步數為4步
# 回合:34
# 3.7861647477877014e-05
# 走出迷宮的總步數為4步
# 回合:35
# 3.479275818274452e-05
# 走出迷宮的總步數為4步
# 回合:36
# 3.196808412941898e-05
# 走出迷宮的總步數為4步
# 回合:37
# 2.936862284397268e-05
# 走出迷宮的總步數為4步
# 回合:38
# 2.6976809319845252e-05
# 走出迷宮的總步數為4步
# 回合:39
# 2.4776411207239057e-05
# 走出迷宮的總步數為4步
# 回合:40
# 2.275243126736992e-05
# 走出迷宮的總步數為4步
# 回合:41
# 2.0891016624502434e-05
# 走出迷宮的總步數為4步
# 回合:42
# 1.917937437345696e-05
# 走出迷宮的總步數為4步
# 回合:43
# 1.760569313313809e-05
# 走出迷宮的總步數為4步
# 回合:44
# 1.615907014573814e-05
# 走出迷宮的總步數為4步
# 回合:45
# 1.4829443564123856e-05
# 走出迷宮的總步數為4步
# 回合:46
# 1.3607529571468824e-05
# 走出迷宮的總步數為4步
# 回合:47
# 1.2484764016829075e-05
# 走出迷宮的總步數為4步
# 回合:48
# 1.1453248253356918e-05
# 走出迷宮的總步數為4步
# 回合:49
# 1.0505698897711468e-05
# 走出迷宮的總步數為4步
# 回合:50
# 9.635401242658048e-06
# 走出迷宮的總步數為4步
# 回合:51
# 8.836166064951634e-06
# 走出迷宮的總步數為4步
# 回合:52
# 8.102289602351931e-06
# 走出迷宮的總步數為4步
# 回合:53
# 7.428516468621638e-06
# 走出迷宮的總步數為4步
# 回合:54
# 6.810005310220468e-06
# 走出迷宮的總步數為4步
# 回合:55
# 6.242297004521724e-06
# 走出迷宮的總步數為4步
# 回合:56
# 5.721285222803907e-06
# 走出迷宮的總步數為4步
# 回合:57
# 5.243189189596542e-06
# 走出迷宮的總步數為4步
# 回合:58
# 4.8045284813946765e-06
# 走出迷宮的總步數為4步
# 回合:59
# 4.402099715972163e-06
# 走出迷宮的總步數為4步
# 回合:60
# 4.032955000510263e-06
# 走出迷宮的總步數為4步
# 回合:61
# 3.6943820064250232e-06
# 走出迷宮的總步數為4步
# 回合:62
# 3.383885555874322e-06
# 走出迷宮的總步數為4步
# 回合:63
# 3.099170607923085e-06
# 走出迷宮的總步數為4步
# 回合:64
# 2.8381265415600154e-06
# 走出迷宮的總步數為4步
# 回合:65
# 2.5988126419740354e-06
# 走出迷宮的總步數為4步
# 回合:66
# 2.3794446982750017e-06
# 走出迷宮的總步數為4步
# 回合:67
# 2.1783826332777423e-06
# 走出迷宮的總步數為4步
# 回合:68
# 1.99411908641256e-06
# 走出迷宮的總步數為4步
# 回合:69
# 1.8252688789299754e-06
# 走出迷宮的總步數為4步
# 回合:70
# 1.6705592962296123e-06
# 走出迷宮的總步數為4步
# 回合:71
# 1.528821125251767e-06
# 走出迷宮的總步數為4步
# 回合:72
# 1.398980389866189e-06
# 走出迷宮的總步數為4步
# 回合:73
# 1.280050730301241e-06
# 走出迷宮的總步數為4步
# 回合:74
# 1.171126382315535e-06
# 走出迷宮的總步數為4步
# 回合:75
# 1.0713757029323645e-06
# 走出迷宮的總步數為4步
# 回合:76
# 9.800352084310404e-07
# 走出迷宮的總步數為4步
# 回合:77
# 8.964040810743867e-07
# 走出迷宮的總步數為4步
# 回合:78
# 8.198391089342394e-07
# 走出迷宮的總步數為4步
# 回合:79
# 7.497500271735902e-07
# 走出迷宮的總步數為4步
# 回合:80
# 6.855952289219758e-07
# 走出迷宮的總步數為4步
# 回合:81
# 6.268778156570676e-07
# 走出迷宮的總步數為4步
# 回合:82
# 5.731419638888013e-07
# 走出迷宮的總步數為4步
# 回合:83
# 5.239695807235378e-07
# 走出迷宮的總步數為4步
# 回合:84
# 4.789772267699277e-07
# 走出迷宮的總步數為4步
# 回合:85
# 4.378132858473549e-07
# 走出迷宮的總步數為4步
# 回合:86
# 4.0015536173498845e-07
# 走出迷宮的總步數為4步
# 回合:87
# 3.657078848640083e-07
# 走出迷宮的總步數為4步
# 回合:88
# 3.3419990974614677e-07
# 走出迷宮的總步數為4步
# 回合:89
# 3.0538309325756074e-07
# 走出迷宮的總步數為4步
# 回合:90
# 2.7902983379402e-07
# 走出迷宮的總步數為4步
# 回合:91
# 2.5493156152744945e-07
# 走出迷宮的總步數為4步
# 回合:92
# 2.3289716855057208e-07
# 走出迷宮的總步數為4步
# 回合:93
# 2.1275156603106637e-07
# 走出迷宮的總步數為4步
# 回合:94
# 1.943343574950518e-07
# 走出迷宮的總步數為4步
# 回合:95
# 1.7749862235572067e-07
# 走出迷宮的總步數為4步
# 回合:96
# 1.6210979714159635e-07
# 走出迷宮的總步數為4步
# 回合:97
# 1.4804464931739147e-07
# 走出迷宮的總步數為4步
# 回合:98
# 1.3519033403852632e-07
# 走出迷宮的總步數為4步
# 回合:99
# 1.2344352906534795e-07
# 走出迷宮的總步數為4步
# 回合:100
# 1.1270964095366764e-07
# 走出迷宮的總步數為4步

# %%
# 將狀態價值的變化繪製成圖
# 參考URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
from matplotlib import animation
from IPython.display import HTML
import matplotlib.cm as cm  # color map


def init():
    # 初始化背景影像
    line.set_data([], [])
    return (line,)


def animate(i):
    # 每一格影格的繪圖內容
    # 在每一格繪製與狀態價值相同大小的彩色四邊形
    line, = ax.plot([0.5], [2.5], marker="s",
                    color=cm.jet(V[i][0]), markersize=85)  # S0
    line, = ax.plot([1.5], [2.5], marker="s",
                    color=cm.jet(V[i][1]), markersize=85)  # S1
    line, = ax.plot([2.5], [2.5], marker="s",
                    color=cm.jet(V[i][2]), markersize=85)  # S2
    line, = ax.plot([0.5], [1.5], marker="s",
                    color=cm.jet(V[i][3]), markersize=85)  # S3
    line, = ax.plot([1.5], [1.5], marker="s",
                    color=cm.jet(V[i][4]), markersize=85)  # S4
    line, = ax.plot([2.5], [1.5], marker="s",
                    color=cm.jet(V[i][5]), markersize=85)  # S5
    line, = ax.plot([0.5], [0.5], marker="s",
                    color=cm.jet(V[i][6]), markersize=85)  # S6
    line, = ax.plot([1.5], [0.5], marker="s",
                    color=cm.jet(V[i][7]), markersize=85)  # S7
    line, = ax.plot([2.5], [0.5], marker="s",
                    color=cm.jet(1.0), markersize=85)  # S8
    return (line,)


#　利用初始化函數與每格影格的繪圖函數繪製動畫
anim = animation.FuncAnimation(
    fig, animate, init_func=init, frames=len(V), interval=200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgc204759725bd4c55b11bdeb09d286172">
#     <br>
#     <input id="_anim_sliderc204759725bd4c55b11bdeb09d286172" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animc204759725bd4c55b11bdeb09d286172.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animc204759725bd4c55b11bdeb09d286172.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animc204759725bd4c55b11bdeb09d286172.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animc204759725bd4c55b11bdeb09d286172.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animc204759725bd4c55b11bdeb09d286172.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animc204759725bd4c55b11bdeb09d286172.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animc204759725bd4c55b11bdeb09d286172.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animc204759725bd4c55b11bdeb09d286172.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animc204759725bd4c55b11bdeb09d286172.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animc204759725bd4c55b11bdeb09d286172.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectc204759725bd4c55b11bdeb09d286172" class="anim_control">
#     <input type="radio" name="state"
#            value="once" checked> Once </input>
#     <input type="radio" name="state"
#            value="loop" > Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc204759725bd4c55b11bdeb09d286172";
#     var slider_id = "_anim_sliderc204759725bd4c55b11bdeb09d286172";
#     var loop_select_id = "_anim_loop_selectc204759725bd4c55b11bdeb09d286172";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvIxREBQAAFTlJREFUeJzt3X2cVXWdwPHPZWZ4FgEBFVDGB9AU\
# UWNQfFjTyMp1KwEVtYc10yx76WvbtdY2Ex+23LUyXbU2Nne13RTTSg3TslYNo9caIlaSRCWJz4Ai\
# CAzjwNk/fpeYGWZgBu/D9x4+79drXgP3nks/jrfP/O7vHM4pZFmWIUkKp1e1ByBJ6pyBlqSgDLQk\
# BWWgJSkoAy1JQRloSQrKQEtSUAZakoIy0JIUlIGWpKAMtCQFZaAlKSgDLUlBGWhJCspAS1JQBlqS\
# gjLQkhSUgZakoAy0JAVloCUpKAMtSUEZaEkKykBLUlAGWpKCMtCSFJSBlqSgDLQkBWWgJSkoAy1J\
# QRloSQrKQEtSUAZakoIy0JIUlIGWpKAMtCQFZaAlKSgDLUlBGWhJCspAS1JQBlqSgjLQkhSUgZak\
# oOqrPYAdMWzYMBobG6s9DEk5s3TpUlasWFHtYfxFTQa6sbGR+fPnV3sYknKmqamp2kNoxyUOSQrK\
# QEtSUDW5xNGp7xegUO1B5EwGTMu6fLpQuKNyY9mJZNmMLp9zn5fHtvZ5NeVnBm2cS899KlVVfgIt\
# STljoCUpKAMtSUEZaEkKykBLUlAGWpKCMtCSFJSBlqSgDLQkBWWgJSkoAy1JQRloSQrKQEtSUAZa\
# koIy0JIUlIGWpKAMtCQFZaAlKSgDLUlBGWhJCspAS1JQBlqSgjLQkhSUgZakoAy0JAVloCUpKAMt\
# SUEZaEkKykBLUlD11R5AHi1/HWbOhh8tgBdfg8EDYPzecMlUOPEwyDK44g6Y9SC8thaOHAs3nQcH\
# 713tkdeq1cCdwBPAKmAAMBr4ADABeAz4KfAMsAb4AnBwVUaaL9va7wcBdwBPAi8D/YqPnQUMq8Zg\
# a5KBLoPpX4Z1G+DmT8H+e8Arr8MjT8HKN9Lz1/wAvnov3HIhHDASrrwTTrwCFt8Iu/Sr7thr07VA\
# C3A+sAcpHIuA4g6nGRgHHAt8vRoDzKlt7fcWYClwCtAIrAP+G7gauAaoq/hoa5GBLrFVa2HuInhw\
# JkyZkB4bMwImjU2/zjK4bg5cMg2mH5Ueu/VCGPFRuO3ncP57qjPu2rUWeBr4PHBI8bHhwH5ttjmu\
# +H11BceVd93Z75/v8JrzgIuB5wE/LnaHa9AlNrBv+rr3V9DcsvXzz7wML62Cdx+65bF+feC4g2De\
# 4sqNMz/6Fr8eJ83aVBk7st/XF78PKMuI8sgZdInV16Wli/O+kdaYD98HjjkQTjsajhyX4gyw++D2\
# r9t9MDz/auXHW/vqgE8Cs4CfkT5OjwMmA2OrN6zc6+l+byUtcUwEdqvMEHPAQJfB9KPg5IlpqeOX\
# v4cHnkhrzl88C44fn7YpFNq/JsugsPUfpW45Ejic9JF7CbAQuA+YAUyt4rjyrrv7fSNwI2kd+jMV\
# HmNtc4mjTPr2TmdsXHY6zLsaPjYFLv8uDBuUnn/ptfbbv/L61rNq9URv0hkb04GrgBOAu0gzN5XP\
# 9vb7RuDfgGeBS4FdqjDG2mWgK+SgvaB1I+y+K+wxGB58cstzzS0w93dw9AHVG1/+jAY24bp0pbXd\
# 763A9aQ4fwFwBtJTLnGU2Mo1cNqX4ZwpMGFMOm1u/h/hmrthyiGw6wD4u7+BL34PDhwN4/aEf74r\
# HVg867jt//nqaA1wHXA86cyAfsCfgHuB8UB/0mlfK0hnHkA6L3cAKRhGY8dsb7/3Ab4G/BH4LGkB\
# r3gAhv6kmbe2x0CX2MC+MHkcXD8H/vASbHgTRu0GZ/0VXHpq2uazU2F9C3xq1pZ/qPKTyzwHesf0\
# BfYH7ieF901gKHAMMK24zXzg39u8Zlbx+3TgtMoMM3e2t99XkvY7wOc6vPYTpLBre
